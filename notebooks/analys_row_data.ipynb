# %% [markdown]
# ### Import All nececary libraries

# %%
import os
import sys
sys.path.append('../scripts')
import EDA as eda
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import sentimentAnalysis as sm
from sklearn.decomposition import LatentDirichletAllocation
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import pandas as pd
import seaborn as sns
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tsegaye\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tsegaye\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tsegaye\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Load Data

# %%
df = eda.LoadData("../data/raw_analyst_ratings.csv")

# %% [markdown]
# ### Inspecting and pre-processing the data

# %%
eda.InspectData(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1407328 entries, 0 to 1407327
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1407328 non-null  int64
#  1   headline    1407328 non-null  object
#  2   url         1407328 non-null  object
#  3   publisher   1407328 non-null  object
#  4   date        1407328 non-null  object
#  5   stock       1407328 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 64.4+ MB

# %%
eda.GetShape(df)
# Out:
# (1407328, 6)

# %%
eda.GetSummary(df)
# Out:
#          Unnamed: 0
# count  1.407328e+06
# mean   7.072454e+05
# std    4.081009e+05
# min    0.000000e+00
# 25%    3.538128e+05
# 50%    7.072395e+05
# 75%    1.060710e+06
# max    1.413848e+06

# %%
eda.GetColumns(df)
# Out:
# Index(['Unnamed: 0', 'headline', 'url', 'publisher', 'date', 'stock'], dtype='object')

# %%
eda.GetColumnNames(df)
# Out:
# ['Unnamed: 0', 'headline', 'url', 'publisher', 'date', 'stock']

# %%
eda.GetColumnTypes(df)
# Out:
# Unnamed: 0     int64
# headline      object
# url           object
# publisher     object
# date          object
# stock         object
# dtype: object

# %% [markdown]
# ### Cleaning the data

# %%
# Check missing value
eda.CheckMissingValue(df)
# Out:
# Unnamed: 0    0
# headline      0
# url           0
# publisher     0
# date          0
# stock         0
# dtype: int64

# %%
# Remove irelevant feature and check it again
eda.RemoveColumn(df)

# %% [markdown]
# ### Perform descriptive statistics

# %% [markdown]
# Calculate the length of headlines to understand the distribution

# %%
eda.GetSummary(df)
# Out:
#                        headline  \
# count                   1407328
# unique                   845770
# top     Benzinga's Top Upgrades
# freq                       5449
#
#                                                       url      publisher  \
# count                                             1407328        1407328
# unique                                             883429           1034
# top     https://www.benzinga.com/news/20/03/15538835/s...  Paul Quintaro
# freq                                                 1704         228373
#
#                        date    stock
# count               1407328  1407328
# unique                39957     6204
# top     2020-03-12 00:00:00      MRK
# freq                   1766     3333

# %%
# Calculate the new's headline lenght
dataFrame = eda.AddHeadlineLength(df)

# %%
dataFrame["headline_length"].head()
# Out:
# 0    39
# 1    42
# 2    29
# 3    44
# 4    87
# Name: headline_length, dtype: int64

# %%
# Let's view the basic statistics of the headline length
eda.GtHeadlineLengthStats(dataFrame)
# Out:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# Examine the publication dates to identify trends over time.

# %%
# Check the length of the date strings
dataFrame['date_length'] = dataFrame['date'].apply(len)
print(dataFrame['date_length'].value_counts())
# Out:
# date_length
# 19    1351341
# 25      55987
# Name: count, dtype: int64

# %%
df = eda.ConvertDdate(dataFrame,"date")
df
# Out:
#                                                   headline  \
# 0                  Stocks That Hit 52-Week Highs On Friday
# 1               Stocks That Hit 52-Week Highs On Wednesday
# 2                            71 Biggest Movers From Friday
# 3             46 Stocks Moving In Friday's Mid-Day Session
# 4        B of A Securities Maintains Neutral on Agilent...
# ...                                                    ...
# 1407323             Top Narrow Based Indexes For August 29
# 1407324  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# 0        https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1        https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2        https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3        https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4        https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
# ...                                                    ...                ...
# 1407323  https://www.benzinga.com/news/11/08/1888782/to...      Monica Gerson
# 1407324  https://www.benzinga.com/news/earnings/11/06/1...       Benjamin Lee
# 1407325  https://www.benzinga.com/analyst-ratings/analy...     BenzingaStaffL
# 1407326  https://www.benzinga.com/analyst-ratings/price...          Joe Young
# 1407327  https://www.benzinga.com/news/ipos/11/05/10789...      Allie Wickman
#
#                        date stock  headline_length  date_length
# 0       2020-06-05 10:30:54     A               39           25
# 1       2020-06-03 10:45:20     A               42           25
# 2       2020-05-26 04:30:07     A               29           25
# 3       2020-05-22 12:45:06     A               44           25
# 4       2020-05-22 11:38:59     A               87           25
# ...                     ...   ...              ...          ...
# 1407323 2011-08-29 00:00:00    ZX               38           19
# 1407324 2011-06-22 00:00:00    ZX               52           19
# 1407325 2011-06-21 00:00:00    ZX               56           19
# 1407326 2011-06-21 00:00:00    ZX               54           19
# 1407327 2011-05-12 00:00:00    ZX               81           19
#
# [1407328 rows x 7 columns]

# %%
formattedData = eda.EctractTimeFormat(dataFrame)

# %%
formattedData.head()
# Out:
#                                             headline  \
# 0            Stocks That Hit 52-Week Highs On Friday
# 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                      71 Biggest Movers From Friday
# 3       46 Stocks Moving In Friday's Mid-Day Session
# 4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                  date stock  headline_length  date_length  year  month  day  \
# 0 2020-06-05 10:30:54     A               39           25  2020      6    5
# 1 2020-06-03 10:45:20     A               42           25  2020      6    3
# 2 2020-05-26 04:30:07     A               29           25  2020      5   26
# 3 2020-05-22 12:45:06     A               44           25  2020      5   22
# 4 2020-05-22 11:38:59     A               87           25  2020      5   22
#
#    hour  minute
# 0    10      30
# 1    10      45
# 2     4      30
# 3    12      45
# 4    11      38

# %%
eda.ArticlePublishedYearly(formattedData)

# %%
eda.HeadlineLength(formattedData)

# %%
eda.TopPublisher(formattedData)
# Out:
# e:\Development\10-Accademy-week-1\notebooks\../scripts\EDA.py:99: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_publishers.index, y=top_publishers.values, palette="viridis")

# %%
eda.YearlyArticlePublished(formattedData)

# %%
eda.DailyArticlesPublishedEachMonth(formattedData)

# %% [markdown]
# Filter data for January of 2018, 2019, and 2020

# %%
eda.ThreeYearJanu(formattedData)

# %% [markdown]
# The number of Article Published Over a time

# %%
eda.NumArticlePubTime(formattedData)

# %% [markdown]
# ### Text Analysis

# %% [markdown]
# # Sentimenet analysis

# %% [markdown]
# Extract headline column for analysis

# %%
headlines = sm.ExtractHeadline(formattedData)

# %% [markdown]
# #### Pre-process text(stopword elimination, stemming)

# %%
ProcessedHeadline =[sm.PreprocessText(headline) for headline in headlines ]

# %% [markdown]
# I use SentimentIntensityAnalyzer from NLTK to determine the sentiment of each headline.

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Tsegaye\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
SA = SentimentIntensityAnalyzer()
sentiments = [SA.polarity_scores(headline)["compound"] for headline in ProcessedHeadline]

# %%
formattedData["sentiment"] = sentiments
formattedData["sentiment_class"] = formattedData["sentiment"].apply(sm.ClassifySentiment)

# %%
formattedData.head(10)
# Out:
#                                             headline  \
# 0            Stocks That Hit 52-Week Highs On Friday
# 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                      71 Biggest Movers From Friday
# 3       46 Stocks Moving In Friday's Mid-Day Session
# 4  B of A Securities Maintains Neutral on Agilent...
# 5  CFRA Maintains Hold on Agilent Technologies, L...
# 6  UBS Maintains Neutral on Agilent Technologies,...
# 7  Agilent Technologies shares are trading higher...
# 8  Wells Fargo Maintains Overweight on Agilent Te...
# 9         10 Biggest Price Target Changes For Friday
#
#                                                  url                publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...        Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...        Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...               Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...               Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...               Vick Meyer
# 5  https://www.benzinga.com/news/20/05/16095163/c...  vishwanath@benzinga.com
# 6  https://www.benzinga.com/news/20/05/16094027/u...  vishwanath@benzinga.com
# 7  https://www.benzinga.com/wiim/20/05/16093805/a...        Benzinga Newsdesk
# 8  https://www.benzinga.com/news/20/05/16093505/w...  vishwanath@benzinga.com
# 9  https://www.benzinga.com/analyst-ratings/price...               Lisa Levin
#
#                  date stock  headline_length  date_length  year  month  day  \
# 0 2020-06-05 10:30:54     A               39           25  2020      6    5
# 1 2020-06-03 10:45:20     A               42           25  2020      6    3
# 2 2020-05-26 04:30:07     A               29           25  2020      5   26
# 3 2020-05-22 12:45:06     A               44           25  2020      5   22
# 4 2020-05-22 11:38:59     A               87           25  2020      5   22
# 5 2020-05-22 11:23:25     A               71           25  2020      5   22
# 6 2020-05-22 09:36:20     A               73           25  2020      5   22
# 7 2020-05-22 09:07:04     A              120           25  2020      5   22
# 8 2020-05-22 08:37:59     A               84           25  2020      5   22
# 9 2020-05-22 08:06:17     A               42           25  2020      5   22
#
#    hour  minute  sentiment sentiment_class
# 0    10      30     0.0000         Neutral
# 1    10      45     0.0000         Neutral
# 2     4      30     0.0000         Neutral
# 3    12      45     0.0000         Neutral
# 4    11      38     0.3400         Neutral
# 5    11      23    -0.2960        Negative
# 6     9      36     0.0000         Neutral
# 7     9       7     0.2960         Neutral
# 8     8      37    -0.1027        Negative
# 9     8       6     0.0000         Neutral

# %% [markdown]
# #### Let's pring out top 10 headlines for each sentiment class

# %%
formattedData[formattedData['sentiment_class'] == 'Positive'].nlargest(10, 'sentiment')
# Out:
#                                                   headline  \
# 603047   Shares of several home improvement companies a...
# 759479   Shares of several home improvement companies a...
# 774253   Shares of several home improvement companies a...
# 294336   Seeing Major Volatility In Low Priced, Low Flo...
# 718097   Seeing Major Volatility In Low Priced, Low Flo...
# 1021482  Seeing Major Volatility In Low Priced, Low Flo...
# 166417   Richard Schottenfeld Decreases Active Barnes A...
# 1356420   13     0       0    -0.5010   Very Negative
# 130229     5     0       0    -0.5023   Very Negative
# 157647     5     0       0    -0.5023   Very Negative
# 287982     5     0       0    -0.5023   Very Negative
# 295864     5     0       0    -0.5023   Very Negative
# 697988     5     0       0    -0.5023   Very Negative
# 899071     5     0       0    -0.5023   Very Negative
# 1090909    5     0       0    -0.5023   Very Negative
# 1204600    5     0       0    -0.5023   Very Negative

# %% [markdown]
# let's see the sentiment score

# %%
sm.sentimentScore(formattedData)

# %% [markdown]
# let's see the sentiment class

# %%
sm.SentimentClass(formattedData)
# Out:
# e:\Development\10-Accademy-week-1\notebooks\../scripts\sentimentAnalysis.py:74: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sentiment_class', data=df, palette='viridis')

# %% [markdown]
# #### Extract key-word and phrases and displays top-n word TF-IDF metods of vectorization

# %% [markdown]
# 1. Comput TF-IDF

# %%
X, feature_names, vocabulary = sm.ComputeTfidf(ProcessedHeadline)

# %%
vocabulary
# Out:
# {'stock': 858,
#  'hit': 393,
#  'week': 969,
#  'high': 389,
#  'friday': 347,
#  'wednesday': 968,
#  'biggest': 87,
#  'mover': 564,
#  'moving': 565,
#  'midday': 539,
#  'session': 806,
#  'security': 794,
#  'maintains': 508,
#  'neutral': 580,
#  'technology': 884,
#  'raise': 709,
#  'price': 682,
#  'target': 878,
#  'hold': 395,
#  'lower': 500,
#  'ubs': 922,
#  'share': 809,
#  'trading': 908,
#  'higher': 390,
#  'company': 180,
#  'reported': 749,
#  'betterthanexpected': 84,
#  'eps': 278,
#  'sale': 785,
#  'result': 758,
#  'fargo': 316,
#  'overweight': 623,
#  'change': 145,
#  'premarket': 673,
#  'outperform': 620,
#  'thursday': 898,
#  'afterhours': 16,
#  'adj': 12,
#  'beat': 75,
#  'estimate': 284,
#  'earnings': 260,
#  'scheduled': 788,
#  'receives': 729,
#  'fda': 319,
#  'approval': 48,
#  'roundup': 777,
#  'adjusted': 13,
#  'portfolio': 664,
#  'square': 844,
#  'fund': 349,
#  'stake': 846,
#  'coronavirus': 196,
#  'market': 517,
#  'volatility': 954,
#  'healthcare': 385,
#  'amid': 34,
#  'positive': 666,
#  'investor': 441,
#  'sentiment': 802,
#  'state': 850,
#  'begin': 76,
#  'economy': 264,
#  'oil': 604,
#  'gain': 354,
#  'dip': 240,
#  'following': 338,
#  'recent': 730,
#  'strength': 864,
#  'sold': 828,
#  'concern': 184,
#  'uschina': 939,
#  'trade': 905,
#  'report': 748,
#  'green': 376,
#  'lab': 470,
#  'fy': 352,
#  'guidance': 381,
#  'auto': 61,
#  'space': 835,
#  'raised': 710,
#  'hope': 399,
#  'return': 762,
#  'economic': 263,
#  'activity': 6,
#  'rebound': 725,
#  'consumer': 188,
#  'spending': 837,
#  'optimism': 613,
#  'case': 133,
#  'stifel': 856,
#  'weakness': 965,
#  'equity': 281,
#  'intl': 438,
#  'air': 23,
#  'chief': 151,
#  'airline': 24,
#  'sector': 793,
#  'sign': 816,
#  'chinese': 153,
#  'continue': 189,
#  'rise': 770,
#  'stimulus': 857,
#  'selling': 798,
#  'demand': 232,
#  'outbreak': 617,
#  'barclays': 69,
#  'equalweight': 279,
#  'chairman': 144,
#  'john': 456,
#  'think': 896,
#  'current': 209,
#  'opportunity': 612,
#  'buy': 117,
#  'citigroup': 158,
#  'low': 499,
#  'monday': 554,
#  'sympathy': 875,
#  'overall': 622,
#  'continued': 190,
#  'momentum': 552,
#  'caused': 137,
#  'virus': 952,
#  'negative': 576,
#  'impact': 410,
#  'global': 365,
#  'basic': 72,
#  'material': 521,
#  'volatile': 953,
#  'note': 589,
#  'fear': 320,
#  'including': 414,
#  'vaccine': 942,
#  'apparel': 43,
#  'medical': 523,
#  'continues': 191,
#  'spread': 842,
#  'say': 787,
#  'january': 449,
#  'net': 577,
#  'revenue': 765,
#  'impacted': 411,
#  'public': 701,
#  'health': 384,
#  'china': 152,
#  'jan': 448,
#  'extension': 308,
#  'new': 581,
#  'year': 993,
#  'day': 220,
#  'month': 556,
#  'selloff': 799,
#  'benzingas': 81,
#  'upgrade': 935,
#  'downgrade': 251,
#  'february': 322,
#  'software': 826,
#  'surge': 873,
#  'announces': 41,
#  'tuesday': 917,
#  'reaffirms': 721,
#  'bb': 73,
#  'est': 282,
#  'inline': 431,
#  'yoy': 998,
#  'watch': 960,
#  'bioscience': 91,
#  'settlement': 808,
#  'deal': 221,
#  'pay': 633,
#  'cowen': 205,
#  'view': 951,
#  'potential': 669,
#  'likely': 486,
#  'event': 290,
#  'additional': 11,
#  'investment': 440,
#  'business': 116,
#  'performance': 641,
#  'seeing': 795,
#  'news': 582,
#  'action': 5,
#  'initiate': 428,
#  'coverage': 203,
#  'rating': 715,
#  'tool': 902,
#  'trader': 907,
#  'cannabis': 128,
#  'prep': 674,
#  'recap': 726,
#  'update': 934,
#  'file': 327,
#  'showing': 815,
#  'hearing': 386,
#  'november': 592,
#  'qtr': 705,
#  'dividend': 247,
#  'nicolaus': 583,
#  'october': 597,
#  'peek': 636,
#  'future': 350,
#  'edge': 265,
#  'ahead': 20,
#  'fed': 323,
#  'president': 678,
#  'trump': 914,
#  'talk': 877,
#  'limited': 488,
#  'meet': 527,
#  'white': 974,
#  'house': 403,
#  'today': 901,
#  'include': 413,
#  'firm': 333,
#  'increase': 417,
#  'tariff': 879,
#  'billion': 88,
#  'worth': 985,
#  'good': 369,
#  'oct': 596,
#  'weak': 964,
#  'job': 454,
#  'uncertainty': 924,
#  'upcoming': 933,
#  'meeting': 528,
#  'minister': 545,
#  'said': 784,
#  'leader': 477,
#  'set': 807,
#  'early': 259,
#  'country': 201,
#  'study': 866,
#  'benzinga': 80,
#  'pro': 688,
#  'morning': 559,
#  'august': 59,
#  'yesterday': 995,
#  'issued': 445,
#  'analyst': 37,
#  'tumble': 918,
#  'data': 216,
#  'preview': 681,
#  'research': 752,
#  'strong': 865,
#  'gold': 367,
#  'tension': 887,
#  'led': 479,
#  'asset': 56,
#  'key': 468,
#  'property': 695,
#  'approved': 49,
#  'use': 940,
#  'mostsearched': 561,
#  'ticker': 899,
#  'july': 463,
#  'bank': 68,
#  'america': 32,
#  'acquire': 2,
#  'instrument': 433,
#  'purchase': 703,
#  'june': 466,
#  'piper': 651,
#  'jaffray': 446,
#  'regarding': 735,
#  'end': 272,
#  'wed': 966,
#  'common': 176,
#  'worsethanexpected': 983,
#  'announced': 39,
#  'deutsche': 236,
#  'macys': 506,
#  'miss': 547,
#  'sp': 834,
#  'march': 514,
#  'alibaba': 27,
#  'steel': 852,
#  'electronic': 268,
#  'dollar': 248,
#  'option': 614,
#  'alert': 26,
#  'mar': 513,
#  'ask': 55,
#  'oi': 603,
#  'close': 164,
#  'ref': 734,
#  'upbeat': 932,
#  'morgan': 558,
#  'stanley': 847,
#  'cut': 212,
#  'highlight': 392,
#  'letter': 480,
#  'related': 742,
#  'eye': 309,
#  'decision': 225,
#  'financial': 331,
#  'term': 888,
#  'disclosed': 242,
#  'cash': 134,
#  'life': 483,
#  'science': 789,
#  'goldman': 368,
#  'buying': 119,
#  'patient': 632,
#  'treatment': 911,
#  'filing': 328,
#  'american': 33,
#  'express': 307,
#  'partner': 628,
#  'increased': 418,
#  'cfo': 142,
#  'water': 962,
#  'upside': 937,
#  'growth': 380,
#  'expectation': 303,
#  'step': 853,
#  'analysis': 36,
#  'cancer': 126,
#  'scientific': 790,
#  'announce': 38,
#  'collaboration': 169,
#  'agreement': 19,
#  'etf': 285,
#  'industry': 425,
#  'chatter': 147,
#  'upgraded': 936,
#  'hour': 402,
#  'mixed': 548,
#  'downbeat': 250,
#  'core': 195,
#  'conference': 185,
#  'retailer': 761,
#  'season': 791,
#  'second': 792,
#  'initial': 427,
#  'earlier': 258,
#  'pharma': 646,
#  'manufacturing': 512,
#  'service': 805,
#  'commercial': 174,
#  'supply': 871,
#  'advanced': 15,
#  'remains': 745,
#  'focus': 337,
#  'jp': 461,
#  'repurchase': 751,
#  'subsidiary': 867,
#  'partnership': 629,
#  'southern': 833,
#  'california': 122,
#  'eli': 270,
#  'lilly': 487,
#  'therapeutic': 894,
#  'evercore': 291,
#  'isi': 443,
#  'group': 378,
#  'sachs': 782,
#  'ceo': 141,
#  'boston': 102,
#  'pharmaceutical': 647,
#  'clinical': 163,
#  'trial': 913,
#  'based': 71,
#  'product': 689,
#  'margin': 515,
#  'expansion': 301,
#  'cell': 138,
#  'gainer': 355,
#  'like': 485,
#  'quarter': 707,
#  'minute': 546,
#  'acquires': 3,
#  'great': 373,
#  'pick': 649,
#  'launch': 475,
#  'social': 825,
#  'jefferies': 452,
#  'care': 132,
#  'solution': 830,
#  'spike': 838,
#  'volume': 955,
#  'outlook': 619,
#  'chair': 143,
#  'annual': 42,
#  'tech': 882,
#  'teva': 891,
#  'genetics': 361,
#  'pressure': 680,
#  'decline': 227,
#  'rev': 764,
#  'watching': 961,
#  'biotech': 92,
#  'idea': 409,
#  'bullish': 115,
#  'list': 490,
#  'pt': 700,
#  'brand': 104,
#  'hitting': 394,
#  'plan': 652,
#  'midmorning': 540,
#  'open': 607,
#  'home': 398,
#  'depot': 234,
#  'profit': 691,
#  'expected': 304,
#  'look': 495,
#  'management': 511,
#  'add': 8,
#  'added': 9,
#  'platform': 654,
#  'help': 388,
#  'applied': 46,
#  'test': 890,
#  'eu': 286,
#  'corp': 197,
#  'baird': 65,
#  'offer': 598,
#  'amp': 35,
#  'contract': 192,
#  'control': 193,
#  'exchange': 298,
#  'flat': 335,
#  'time': 900,
#  'jump': 464,
#  'transaction': 909,
#  'order': 616,
#  'reporting': 750,
#  'acquisition': 4,
#  'heavy': 387,
#  'rumor': 779,
#  'aug': 58,
#  'sweep': 874,
#  'final': 329,
#  'phase': 648,
#  'multiple': 566,
#  'mad': 507,
#  'medicine': 524,
#  'buyback': 118,
#  'loser': 497,
#  'outfitter': 618,
#  'lead': 476,
#  'drop': 254,
#  'fall': 313,
#  'calendar': 121,
#  'national': 571,
#  'unit': 929,
#  'notable': 588,
#  'apple': 44,
#  'facebook': 311,
#  'mcdonalds': 522,
#  'awarded': 64,
#  'street': 863,
#  'primer': 685,
#  'tax': 880,
#  'japan': 450,
#  'narrow': 569,
#  'nyse': 595,
#  'laboratory': 471,
#  'highest': 391,
#  'roe': 774,
#  'patent': 631,
#  'universal': 931,
#  'midcap': 538,
#  'reiterates': 741,
#  'presentation': 677,
#  'enters': 276,
#  'distribution': 246,
#  'feb': 321,
#  'currently': 210,
#  'pricing': 683,
#  'offering': 599,
#  'split': 840,
#  'ibm': 407,
#  'received': 728,
#  'senior': 801,
#  'september': 804,
#  'board': 99,
#  'special': 836,
#  'pres': 675,
#  'coo': 194,
#  'yield': 996,
#  'technical': 883,
#  'support': 872,
#  'mobile': 550,
#  'wireless': 978,
#  'communication': 177,
#  'gaap': 353,
#  'th': 893,
#  'resource': 755,
#  'po': 660,
#  'james': 447,
#  'named': 568,
#  'biogen': 89,
#  'join': 458,
#  'director': 241,
#  'midafternoon': 537,
#  'development': 237,
#  'nov': 590,
#  'december': 224,
#  'western': 973,
#  'union': 928,
#  'post': 668,
#  'game': 356,
#  'traded': 906,
#  'strategic': 861,
#  'valuation': 943,
#  'moody': 557,
#  'lowered': 501,
#  'aid': 21,
#  'capital': 131,
#  'solid': 829,
#  'weekly': 971,
#  'come': 171,
#  'confirms': 186,
#  'jim': 453,
#  'cramer': 206,
#  'expecting': 305,
#  'credit': 207,
#  'suisse': 868,
#  'review': 766,
#  'sell': 797,
#  'slightly': 821,
#  'forecast': 341,
#  'jobless': 455,
#  'claim': 160,
#  'issue': 444,
#  'remain': 744,
#  'appoints': 47,
#  'customer': 211,
#  'million': 542,
#  'guide': 382,
#  'compare': 181,
#  'barrons': 70,
#  'medium': 525,
#  'summary': 869,
#  'european': 289,
#  'holder': 396,
#  'mon': 553,
#  'license': 482,
#  'nasdaq': 570,
#  'bid': 85,
#  'announcement': 40,
#  'online': 605,
#  'holding': 397,
#  'power': 671,
#  'short': 813,
#  'information': 426,
#  'pending': 638,
#  'charge': 146,
#  'drug': 255,
#  'expect': 302,
#  'officer': 601,
#  'program': 692,
#  'long': 493,
#  'financials': 332,
#  'industrials': 424,
#  'slide': 820,
#  'gross': 377,
#  'looking': 496,
#  'expects': 306,
#  'world': 981,
#  'total': 903,
#  'gas': 359,
#  'rally': 712,
#  'need': 575,
#  'merger': 530,
#  'seen': 796,
#  'digital': 239,
#  'ratio': 716,
#  'natural': 572,
#  'period': 643,
#  'loss': 498,
#  'silver': 819,
#  'greece': 374,
#  'policy': 662,
#  'bond': 100,
#  'chemical': 149,
#  'center': 139,
#  'india': 422,
#  'money': 555,
#  'lightning': 484,
#  'round': 776,
#  'operation': 609,
#  'performing': 642,
#  'catalyst': 135,
#  'brief': 109,
#  'ebay': 261,
#  'blog': 96,
#  'alcoa': 25,
#  'track': 904,
#  'zacks': 999,
#  'addition': 10,
#  'best': 82,
#  'press': 679,
#  'release': 743,
#  'lowest': 503,
#  'peg': 637,
#  'retail': 760,
#  'purchased': 704,
#  'make': 510,
#  'regulatory': 738,
#  'big': 86,
#  'corporation': 199,
#  'resume': 759,
#  'fitch': 334,
#  'black': 93,
#  'according': 1,
#  'opinion': 610,
#  'level': 481,
#  'quarterly': 708,
#  'operating': 608,
#  'despite': 235,
#  'euro': 287,
#  'aig': 22,
#  'april': 52,
#  'insurance': 434,
#  'google': 370,
#  'enterprise': 275,
#  'index': 421,
#  'realty': 723,
#  'trust': 915,
#  'form': 343,
#  'joint': 459,
#  'venture': 947,
#  'position': 665,
#  'closing': 165,
#  'daily': 215,
#  'strategy': 862,
#  'johnson': 457,
#  'federal': 324,
#  'reserve': 753,
#  'uk': 923,
#  'small': 822,
#  'record': 731,
#  'response': 756,
#  'gap': 358,
#  'solar': 827,
#  'energy': 274,
#  'commodity': 175,
#  'rising': 771,
#  'boost': 101,
#  'executive': 300,
#  'date': 217,
#  'loan': 491,
#  'increasing': 419,
#  'number': 593,
#  'real': 722,
#  'estate': 283,
#  'recovery': 732,
#  'weekend': 970,
#  'entertainment': 277,
#  'risk': 772,
#  'international': 436,
#  'city': 159,
#  'source': 831,
#  'jones': 460,
#  'fbr': 318,
#  'court': 202,
#  'bloomberg': 97,
#  'shipping': 812,
#  'rate': 714,
#  'falling': 314,
#  'emerging': 271,
#  'aapl': 0,
#  'corporate': 198,
#  'internet': 437,
#  'output': 621,
#  'comcast': 170,
#  'way': 963,
#  'wall': 958,
#  'restaurant': 757,
#  'going': 366,
#  'fxi': 351,
#  'cloud': 166,
#  'private': 687,
#  'benefit': 79,
#  'canadian': 125,
#  'housing': 404,
#  'ipo': 442,
#  'point': 661,
#  'pop': 663,
#  'progress': 693,
#  'turn': 919,
#  'safety': 783,
#  'metal': 531,
#  'interim': 435,
#  'win': 976,
#  'project': 694,
#  'regional': 736,
#  'income': 415,
#  'finance': 330,
#  'government': 372,
#  'canada': 124,
#  'mark': 516,
#  'family': 315,
#  'fast': 317,
#  'nd': 573,
#  'mining': 544,
#  'average': 63,
#  'receive': 727,
#  'alternative': 30,
#  'fuel': 348,
#  'proposal': 696,
#  'exclusive': 299,
#  'production': 690,
#  'cost': 200,
#  'flow': 336,
#  'petroleum': 644,
#  'drilling': 253,
#  'central': 140,
#  'class': 161,
#  'north': 587,
#  'proposed': 697,
#  'provides': 699,
#  'reach': 720,
#  'smith': 824,
#  'payment': 634,
#  'box': 103,
#  'plc': 656,
#  'play': 655,
#  'major': 509,
#  'lp': 504,
#  'imperial': 412,
#  'defense': 229,
#  'shareholder': 810,
#  'food': 339,
#  'ad': 7,
#  'department': 233,
#  'red': 733,
#  'statement': 851,
#  'present': 676,
#  'marketing': 518,
#  'mexico': 532,
#  'hotel': 401,
#  'st': 845,
#  'debt': 222,
#  'travel': 910,
#  'facility': 312,
#  'work': 980,
#  'trend': 912,
#  'build': 113,
#  'completes': 183,
#  'general': 360,
#  'pacific': 624,
#  'paper': 627,
#  'rose': 775,
#  'dynamic': 256,
#  'network': 579,
#  'line': 489,
#  'significant': 818,
#  'cable': 120,
#  'education': 266,
#  'warner': 959,
#  'pipeline': 650,
#  'amazon': 31,
#  'office': 600,
#  'united': 930,
#  'south': 832,
#  'australia': 60,
#  'start': 849,
#  'electronics': 269,
#  'biopharma': 90,
#  'right': 768,
#  'value': 944,
#  'usa': 938,
#  'ebitda': 262,
#  'huge': 405,
#  'worldwide': 982,
#  'incorporated': 416,
#  'shelf': 811,
#  'bancorp': 66,
#  'canaccord': 123,
#  'declares': 226,
#  'rig': 767,
#  'delta': 231,
#  'david': 218,
#  'provide': 698,
#  'industrial': 423,
#  'rallied': 711,
#  'past': 630,
#  'reopening': 747,
#  'potentially': 670,
#  'better': 83,
#  'pandemic': 625,
#  'bmo': 98,
#  'mgmt': 533,
#  'possible': 667,
#  'candidate': 127,
#  'riley': 769,
#  'mm': 549,
#  'prior': 686,
#  'apr': 51,
#  'showed': 814,
#  'jun': 465,
#  'construction': 187,
#  'tesla': 889,
#  'unconfirmed': 925,
#  'underperform': 926,
#  'dow': 249,
#  'jul': 462,
#  'near': 574,
#  'signal': 817,
#  'perform': 640,
#  'texas': 892,
#  'netflix': 578,
#  'downgraded': 252,
#  'inventory': 439,
#  'crude': 208,
#  'plunge': 658,
#  'argus': 53,
#  'russia': 781,
#  'macquarie': 505,
#  'range': 713,
#  'min': 543,
#  'bull': 114,
#  'bear': 74,
#  'remove': 746,
#  'pm': 659,
#  'plant': 653,
#  'tues': 916,
#  'dec': 223,
#  'automotive': 62,
#  'tell': 886,
#  'tweet': 920,
#  'spiking': 839,
#  'late': 474,
#  'fri': 346,
#  'reuters': 763,
#  'comment': 173,
#  'td': 881,
#  'thurs': 897,
#  'afternoon': 17,
#  'belief': 77,
#  'cnbc': 167,
#  'coming': 172,
#  'primary': 684,
#  'large': 472,
#  'chipotle': 155,
#  'ford': 340,
#  'citi': 157,
#  'qualcomm': 706,
#  'reason': 724,
#  'horizon': 400,
#  'verizon': 948,
#  'block': 95,
#  'article': 54,
#  'takeover': 876,
#  'registration': 737,
#  'longterm': 494,
#  'initiation': 430,
#  'initiated': 429,
#  'twitter': 921,
#  'approves': 50,
#  'vote': 956,
#  'sterne': 855,
#  'agee': 18,
#  'caterpillar': 136,
#  'nomura': 586,
#  'martin': 519,
#  'york': 997,
#  'yahoo': 992,
#  'lockheed': 492,
#  'micron': 535,
#  'sep': 803,
#  'face': 310,
#  'europe': 288,
#  'fresh': 345,
#  'saudi': 786,
#  'noble': 584,
#  'vehicle': 946,
#  'semiconductor': 800,
#  'worst': 984,
#  'smallcap': 823,
#  'pandora': 626,
#  'store': 860,
#  'mountain': 563,
#  'wrap': 986,
#  'brazil': 105,
#  'da': 214,
#  'davidson': 219,
#  'cap': 130,
#  'climb': 162,
#  'jc': 451,
#  'penney': 639,
#  'disney': 245,
#  'brent': 108,
#  'leading': 478,
#  'spokesperson': 841,
#  'cv': 213,
#  'reinstates': 739,
#  'greek': 375,
#  'community': 178,
#  'prelim': 672,
#  'gilead': 363,
#  'reit': 740,
#  'halted': 383,
#  'spy': 843,
#  'chip': 154,
#  'winner': 977,
#  'rbc': 718,
#  'fedex': 325,
#  'xlf': 989,
#  'decliners': 228,
#  'rd': 719,
#  'gld': 364,
#  'electric': 267,
#  'plummet': 657,
#  'xlk': 990,
#  'raymond': 717,
#  'cantor': 129,
#  'michael': 534,
#  'circuit': 156,
#  'breaker': 106,
#  'fox': 344,
#  'delivery': 230,
#  'covid': 204,
#  'model': 551,
#  'underweight': 927,
#  'equipment': 280,
#  'ex': 297,
#  'resort': 754,
#  'dish': 244,
#  'application': 45,
#  'check': 148,
#  'motor': 562,
#  'stephen': 854,
#  'ffo': 326,
#  'suntrust': 870,
#  'robinson': 773,
#  'humphrey': 406,
#  'keybanc': 469,
#  'lowes': 502,
#  'comp': 179,
#  'weight': 972,
#  'merck': 529,
#  'genuity': 362,
#  'insider': 432,
#  'novartis': 591,
#  'blackberry': 94,
#  'telecom': 885,
#  'microsoft': 536,
#  'gopro': 371,
#  'cocacola': 168,
#  'oppenheimer': 611,
#  'broadcom': 111,
#  'disease': 243,
#  'pfizer': 645,
#  'wedbush': 967,
#  'nvidia': 594,
#  'mastercard': 520,
#  'medtronic': 526,
#  'opec': 606,
#  'device': 238,
#  'gaming': 357,
#  'staple': 848,
#  'oracle': 615,
#  'therapy': 895,
#  'benchmark': 78,
#  'ewj': 294,
#  'alliance': 29,
#  'keefe': 467,
#  'bruyette': 112,
#  'wood': 979,
#  'pulse': 702,
#  'largecap': 473,
#  'endpoint': 273,
#  'allergan': 28,
#  'mylan': 567,
#  'bristolmyers': 110,
#  'astrazeneca': 57,
#  'offshore': 602,
#  'mortgage': 560,
#  'adobe': 14,
#  'chesapeake': 150,
#  'yelp': 994,
#  'eagle': 257,
#  'ewc': 293,
#  'utility': 941,
#  'pdufa': 635,
#  'russell': 780,
#  'compass': 182,
#  'wunderlich': 987,
#  'storage': 859,
#  'midstream': 541,
#  'nokia': 585,
#  'brean': 107,
#  'williams': 975,
#  'icahn': 408,
#  'groupon': 379,
#  'xle': 988,
#  'vi': 950,
#  'bancshares': 67,
#  'eww': 295,
#  'rsx': 778,
#  'xrt': 991,
#  'inda': 420,
#  'ewz': 296,
#  'vpu': 957,
#  'ewa': 292,
#  'vdc': 945,
#  'vgk': 949,
#  'forexlive': 342}

# %% [markdown]
# 2. Extract top keywords

# %%
top_keywords = sm.ExtractTopKeywords(X, vocabulary, top_n=10)

# %%
print(top_keywords)
# Out:
# [('stock', 53056.551632364106), ('est', 45364.79407036436), ('eps', 37660.95134333571), ('report', 36756.66024351621), ('market', 32859.805867782845), ('share', 32811.95739218738), ('earnings', 31765.628616182174), ('benzingas', 29351.765017803857), ('downgrade', 25737.08988184621), ('update', 25013.763900665715)]

# %% [markdown]
# 3. Display top keywords

# %%
word_freq = sm.DisplayKeywords(top_keywords)
# Out:
# Top Keywords:
# stock: 53056.551632364106
# est: 45364.79407036436
# eps: 37660.95134333571
# report: 36756.66024351621
# market: 32859.805867782845
# share: 32811.95739218738
# earnings: 31765.628616182174
# benzingas: 29351.765017803857
# downgrade: 25737.08988184621
# update: 25013.763900665715

# %% [markdown]
# let's visualize the top keyword - frequency as a data frame

# %%
sm.ConvertTopKeywordsToDF(top_keywords)
# Out:
# e:\Development\10-Accademy-week-1\notebooks\../scripts\sentimentAnalysis.py:145: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='TF-IDF Score', y='Word', data=top_keywords_df, palette='viridis')

# %% [markdown]
# Let's see word cloud for top key words

# %%
sm.VisualizeKeywords(vocabulary,top_keywords)
# Out:
# e:\Development\10-Accademy-week-1\notebooks\../scripts\sentimentAnalysis.py:180: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_words, y=top_freqs, palette='viridis')

# %% [markdown]
#  Perform topic modeling using Latent Dirichlet Allocation (LDA)

# %%
# Initialize LDA



lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(X)

# Display top words per topic
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic #{topic_idx}:")
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

display_topics(lda, feature_names, 10)
# Out:
# Topic #0:
# benzingas upgrade downgrade morgan option alert stanley volume contract jp
# Topic #1:
# share market stock session moving update higher trading premarket say
# Topic #2:
# est eps report sale revenue industry fy adj estimate highest
# Topic #3:
# pt buy earnings raise scheduled maintains target price neutral initiate
# Topic #4:
# week stock etf biggest high watch mover low yesterday hit

# %% [markdown]
# Generate Word Cloud Visualize the most common words in the headlines.

# %%
# Generate word cloud


text = ' '.join(ProcessedHeadline)
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Headlines')
plt.show()

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# 1. Publication Frequency Over Time Aggregate Data by Date

# %%
# Aggregate by date and count articles

daily_article_counts = formattedData.groupby(formattedData['date'].dt.date).size()
daily_article_counts = daily_article_counts.reset_index(name='article_count')
daily_article_counts['date'] = pd.to_datetime(daily_article_counts['date'])

# %%
daily_article_counts['date']
# Out:
# 0      2009-02-14
# 1      2009-04-27
# 2      2009-04-29
# 3      2009-05-22
# 4      2009-05-27
#           ...
# 3950   2020-06-07
# 3951   2020-06-08
# 3952   2020-06-09
# 3953   2020-06-10
# 3954   2020-06-11
# Name: date, Length: 3955, dtype: datetime64[ns]

# %%
daily_article_counts
# Out:
#            date  article_count
# 0    2009-02-14              1
# 1    2009-04-27              2
# 2    2009-04-29              1
# 3    2009-05-22              1
# 4    2009-05-27              6
# ...         ...            ...
# 3950 2020-06-07             25
# 3951 2020-06-08            765
# 3952 2020-06-09            804
# 3953 2020-06-10            806
# 3954 2020-06-11            544
#
# [3955 rows x 2 columns]

# %% [markdown]
# Let's create a time series plot to visualize how article publication frequency changes over time.

# %%
plt.figure(figsize=(12, 6))
plt.plot(daily_article_counts['date'], daily_article_counts['article_count'], marker='o', linestyle='-', color='b')
plt.title('Daily Article Publication Frequency')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Identify Spikes

# %%
plt.figure(figsize=(12, 6))
plt.plot(daily_article_counts['date'], daily_article_counts['article_count'], marker='o', linestyle='-', color='b')
plt.title('Daily Article Publication Frequency')
plt.xlabel('Date')
plt.ylabel('Number of Articles')
plt.grid(True)
plt.xticks(rotation=45)

# Example: Adding a vertical line for a specific date
plt.axvline(pd.Timestamp('2020-05-22'), color='r', linestyle='--', label='Market Event')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Let's Extract the hour of the day and day of the week from the date column to analyze publishing patterns.

# %%
formattedData['hour'] = formattedData['date'].dt.hour
formattedData['day_of_week'] = formattedData['date'].dt.day_name()

formattedData['hour']
# Out:
# 0          10
# 1          10
# 2           4
# 3          12
# 4          11
#            ..
# 1407323     0
# 1407324     0
# 1407325     0
# 1407326     0
# 1407327     0
# Name: hour, Length: 1407328, dtype: int32

# %%
# Aggregate by hour and day of the week
hourly_article_counts = formattedData.groupby('hour').size()
weekly_article_counts = formattedData.groupby('day_of_week').size()
hourly_article_counts
# Out:
# hour
# 0     1351408
# 1          14
# 2          57
# 3          93
# 4        1469
# 5        1829
# 6        2476
# 7        5033
# 8        5527
# 9        5965
# 10       7669
# 11       5701
# 12       5732
# 13       2710
# 14       2075
# 15       1612
# 16       3939
# 17       2800
# 18        704
# 19        227
# 20        131
# 21         82
# 22         48
# 23         27
# dtype: int64

# %% [markdown]
# Create plots to visualize publishing patterns throughout the day and week.

# %%
# Hourly Publication Frequency
plt.figure(figsize=(12, 6))
plt.bar(hourly_article_counts.index, hourly_article_counts.values, color='g')
plt.title('Article Publication Frequency by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Articles')
plt.grid(True)
plt.xticks(range(0, 24))
plt.tight_layout()
plt.show()

# Weekly Publication Frequency
plt.figure(figsize=(12, 6))
sns.barplot(x=weekly_article_counts.index, y=weekly_article_counts.values, palette='viridis')
plt.title('Article Publication Frequency by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Number of Articles')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Tsegaye\AppData\Local\Temp\ipykernel_5772\3578305812.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=weekly_article_counts.index, y=weekly_article_counts.values, palette='viridis')

# %% [markdown]
# Count the number of articles published by each publisher.

# %%
publisher_counts = formattedData['publisher'].value_counts()
top_publishers = publisher_counts.head(10)
publisher_counts
# Out:
# publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64

# %%
top_publishers
# Out:
# publisher
# Paul Quintaro        228373
# Lisa Levin           186979
# Benzinga Newsdesk    150484
# Charles Gross         96732
# Monica Gerson         82380
# Eddie Staley          57254
# Hal Lindon            49047
# ETF Professor         28489
# Juan Lopez            28438
# Benzinga Staff        28114
# Name: count, dtype: int64

# %% [markdown]
# Let's create a bar plot to visualize the top publishers by the number of articles.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=top_publishers.index, y=top_publishers.values, palette='viridis')
plt.title('Top Publishers by Number of Articles')
plt.xlabel('Publisher')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Tsegaye\AppData\Local\Temp\ipykernel_5772\2395139885.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_publishers.index, y=top_publishers.values, palette='viridis')
